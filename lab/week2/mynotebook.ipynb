# %% [markdown]
# # 나의 프로젝트 노트입니다. 중요한 코드나 문서를 함께 사용할 거에요.
#
# * 작성일: 2026.9.8
# * 작성자: 이원준
#
# 그 외에 표나 그림 등도 넣을 수 있습니다.

# %%
print("Hello, World")
x = 3
print("x=", x)
# Out:
# Hello, World
# x= 3

# %%
이 알고리즘은 아주 간단합니다.
